# %%
import requests

#HTML코드 받아오기
response = requests.get("https://workey.codeit.kr/music/index")

#결과 출력
print(response.text)
# Out:
# <!DOCTYPE html>
# <html lang="ko">
# <head>
#   <script src="https://cdn.jsdelivr.net/npm/vue/dist/vue.js"></script>
#   <script src="https://unpkg.com/axios/dist/axios.min.js"></script>
#   <meta charset="UTF-8">
#   <title>Codeit Music</title>
#   <style>
#     body {
#       margin: 0;
#     }
#
#     a {
#       text-decoration: none;
#       color: inherit;
#     }
#
#     img {
#       vertical-align: middle;
#     }
#
#     ul {
#       list-style: none;
#       padding: 0;
#       margin: 0;
#     }
#
#     * {
#       box-sizing: border-box;
#     }
#
#     .header {
#       position: fixed;
#       top: 0;
#       left: 0;
#       width: 100%;
#       height: 60px;
#       background-color: #ffffff;
#       overflow: hidden;
#       z-index: 1;
#     }
#
#     .nav-warpper {
#       max-width: 1163px;
#       margin: 0 auto;
#       height: 100%;
#       line-height: 60px;
#       padding: 0 20px
#     }
#
#     .header__logo .logo-img {
#       width: 34px;
# ...

# %%
from bs4 import BeautifulSoup

soup = BeautifulSoup(response.text, 'html.parser')

#결과 출력
#print(soup)

#"popular__order" 클래스를 가진 태그에 중첩된 모든 <li> 태그 선택
li_tags = soup.select(".popular__order li")

popular_artists = []

for li in li_tags:
    #텍스트 추출해서 리스트에 담는데 공백 제거하기
    popular_artists.append(li.text.strip())
    
print(popular_artists)
# Out:
# ['1 아이유 (IU)', '2 방탄소년단', '3 Red Velvet (레드벨벳)', '4 IKON', '5 멜로망스', '6 다비치', '7 윤딴딴', '8 수지 (SUZY)', '9 김동률', '10 폴킴']

# %%
#해미 코드

import requests
from bs4 import BeautifulSoup

# 코드를 작성하세요

response = requests.get("https://workey.codeit.kr/orangebottle/index")
soup = BeautifulSoup(response.text, 'html.parser')

#container class 안의 span tag들을 모조리 가져와라
phone = soup.select(".container span")
#print(phone_num)
phone_numbers = []
for li in phone:
    #span 태그안의 text만 추출하기
    phone_numbers.append(li.text)
    
#print(response.text)

# 결과 출력
print(phone_numbers)
# Out:
# ['707-514-0033', '070 3460 5076', '905-389-4463', '(02) 6175 8642', '07183 30 07 96', '21-90-47700', '33 36175334', '845-857-0825', '507-876-0713', '773-757-1932', '301-787-8206', '310-718-6212', '781-646-1715', '315-576-8242', '650-577-7537', '229-460-4970', '305-540-4990', '606-614-9190', '814-965-6502', '8134-191-6900', '914-933-3946', '801-927-7191', '736 301 706', '916-863-6154', '252-218-2526', '803-535-5627', '580-730-2253', '240-597-0099', '210-727-9560', '919-887-6912', '614-449-8617', '830-229-4983', '303-284-0638', '734-981-4470', '701-496-3125', '605-677-5038', '209-848-9572', '760-464-6831', '508-272-0114', '845-915-5076', '973-640-3581', '541-579-1559', '336-212-0408', '845-340-3808', '561-526-2625', '801-608-1332', '510-214-0266', '785-253-0084', '585-749-2163', '312-362-2484', '570-603-5788', '802-738-8477', '507-771-8684', '720-634-0176', '313-930-0331', '8188-165-7118', '02-455-1973']

# %%
#정답 코드
import requests
from bs4 import BeautifulSoup

# HTML 코드 받아오기
response = requests.get("https://workey.codeit.kr/orangebottle/index")

# BeautifulSoup 타입으로 변환
soup = BeautifulSoup(response.text, 'html.parser')

# "phoneNum" 클래스를 가진 태그 선택하기
phoneNum_tags = soup.select('.phoneNum')

# 빈 리스트 생성
phone_numbers = []

# 텍스트 추출해서 리스트에 담기
for tag in phoneNum_tags:
    phone_numbers.append(tag.text)

# %%
import requests
from bs4 import BeautifulSoup

# 코드를 작성하세요
response = requests.get("https://workey.codeit.kr/music/index")
soup = BeautifulSoup(response.text, 'html.parser')
search = soup.select(".rank__order li")

#print(search)
# 결과 출력

search_ranks = []

#strip()함수는 문자열의 처음과 마지막에 있는 공백 문자를 제거
#split(' ') 을 적용하면 공백('')을 기준으로 문자열을 분리해 줌
for li in search:
    search_ranks.append(li.text.strip().split(' ')[2])

print(search_ranks)
# Out:
# ['Queen', '방탄소년단', '아이유', '거미', '폴킴', '김범수', '헤이즈', '트와이스', '박효신', '신용재']

# %% [markdown]
# 필요한 페이지만 가져오기

# %% [markdown]
# 방법 1 : 파싱으로 페이지 개수 알아내기

# %%
response = requests.get("https://www.ikea.com/kr/ko/search/?query=desk")
soup = BeautifulSoup(response.text, 'html.parser')

#마지막 <a> 태그의 텍스트 추출하기
page_length = soup.select('.pagination a')[-1].text

# 빈 리스트 생성
pages = []

#실제 페이지 개수만큼만 HTML 코드 받아오기
for i in range(1, int(page_length) + 1):
    response = requests.get("https://www.ikea.com/kr/ko/search/?query=desk&pageNumber=" + str(i))
    pages.append(response.text)

print(len(pages))
# Out:
# 12

# %% [markdown]
# 방법 2 : 일단 가져와서 확인하기 - 만약 전체 페이지 개수가 사이트에 드러나지 않는다면.. 페이지를 계속 가져오다가, 빈 페이지를 만나면 중단

# %%
pages = []

page_num = 1

while True:
    #HTML 코드 받아오기
    response = requests.get("https://www.ikea.com/kr/ko/search/?query=desk&pageNumber=" + str(page_num))
    
    #BeautifulSoup 타입으로 변환하기
    soup = BeautifulSoup(response.text, 'html.parser')
    
    # ".prodName" 클래스가 있을 때만 HTML 코드를 리스트에 담기
    if len(soup.select('.prodName'))>0:
        pages.append(soup)
        page_num +=1
    else:
        break
        
#가져온 페이지 개수 출력
print(len(pages))
# Out:
# 12

# %%
year=2010
month = 1
week = 0

year_cnt = 0
month_cnt = 0
week_cnt = 0

rating_pages = []
while True:
    response = requests.get("https://workey.codeit.kr/ratings/index?year={0}&month={1}&weekIndex={2}".format(year, month, week))

    soup = BeautifulSoup(response.text, 'html.parser')
    #print(soup.select(".row td"))
    if len(soup.select(".row td")) > 0:
        week+=1
        week_cnt +=1
    else:
        week = 0
        break;   

while True:
    response = requests.get("https://workey.codeit.kr/ratings/index?year={0}&month={1}&weekIndex={2}".format(year, month, week))

    soup = BeautifulSoup(response.text, 'html.parser')
    #print(soup.select(".row td"))
    if len(soup.select(".row td")) > 0:
        month+=1
        month_cnt +=1
    else:
        month=1
        break;   

while True:
    response = requests.get("https://workey.codeit.kr/ratings/index?year={0}&month={1}&weekIndex={2}".format(year, month, week))

    soup = BeautifulSoup(response.text, 'html.parser')
    #print(soup.select(".row td"))
    if len(soup.select(".row td")) > 0:
        year+=1
        year_cnt +=1
    else:
        year=2010
        break;   

#print(year_cnt)
#print(month_cnt)
#print(week_cnt)
for i in range(year, year+year_cnt):
    for j in range(month, month+month_cnt):
        for k in range(week, week+week_cnt):
            response = requests.get("https://workey.codeit.kr/ratings/index?year={0}&month={1}&weekIndex={2}".format(i, j, k))
            rating_pages.append(response.text)
        
print(len(rating_pages)) # 가져온 총 페이지 수 
print(rating_pages[0]) # 첫 번째 페이지의 HTML 코드
# Out:
# 540
# <!DOCTYPE html>
# <html lang="ko">
# <head>
#   <title>티비랭킹닷컴</title>
#   <meta charset="utf-8">
#   <link href="https://fonts.googleapis.com/css?family=Noto+Sans+KR" rel="stylesheet">
#   <style>
#     /* body start */
#     body {
#       font-family: 'Noto Sans KR', sans-serif;
#       margin: 0;
#     }
#
#     /* navigation bar start */
#     .nav-bar {
#       position: fixed;
#       width: 100%;
#       padding-top: 10px;
#       padding-bottom: 10px;
#       background-color: #ffffff;
#       box-shadow: 0 2px 4px 0 rgba(0, 0, 0, 0.14);
#       z-index: 1;
#     }
#
#     .nav-bar #tv-image {
#       margin-left: 78px;
#       margin-right: 15px;
#       height: 36px;
#       vertical-align: middle;
#     }
#
#     .nav-bar span {
#       font-weight: bold;
#       color: #4a4a4a;
#     }
#
#     /* date picker start */
#     .date-pick {
#       padding-top: 56px;
#       height: 200px;
#       background-color: #efefef;
#       margin-left: auto;
# ...

# %%
import requests
from bs4 import BeautifulSoup

year=2010
month = 1
week = 0

rating_pages = []
while True:
    response = requests.get("https://workey.codeit.kr/ratings/index?year={0}&month={1}&weekIndex={2}".format(year, month, week))
    soup = BeautifulSoup(response.text, 'html.parser')
    if len(soup.select('.row td')) > 0:
        rating_pages.append(response.text)
        week += 1
    else:
        total_weeks = week
        week = 0
        break

print(total_weeks)
print(len(rating_pages)
while True:
#     for li in range(0, total_weeks):
#         response = requests.get("https://workey.codeit.kr/ratings/index?year={0}&month={1}&weekIndex={2}".format(year, month, li))
#         soup = BeautifulSoup(response.text, 'html.parser')
#         if len(soup.select('.row td')) > 0:
#             rating_pages.append(response.text)
#             month +=1
#         else:
#             total_months = month
#             month=1
# Out:
#   File "<ipython-input-86-48225bf88207>", line 33
#
#     ^
# SyntaxError: unexpected EOF while parsing

# %%
import requests
from bs4 import BeautifulSoup

year=2010
month = 1
week = 0

rating_pages = []
total_weeks = 0
total_months=0
while True:
    response = requests.get("https://workey.codeit.kr/ratings/index?year={0}&month={1}&weekIndex={2}".format(year, month, week))
    soup = BeautifulSoup(response.text, 'html.parser')
    if len(soup.select('.row td'))>0:
        week += 1
    else:
        total_weeks = week
        week = 0
        break


while True:
    response = requests.get("https://workey.codeit.kr/ratings/index?year={0}&month={1}&weekIndex={2}".format(year, month, week))
    soup = BeautifulSoup(response.text, 'html.parser')
    if len(soup.select('.row td')) > 0:
        month+=1
        
    else:
        total_months = month
        month = 1
        break
        
    
            
for i in range(1, total_months):
    for j in range(0, total_weeks-1):
        while True:
            response = requests.get("https://workey.codeit.kr/ratings/index?year={0}&month={1}&weekIndex={2}".format(year, i, j))
            soup = BeautifulSoup(response.text, 'html.parser')
            if len(soup.select('.row td')) > 0:
                rating_pages.append(response.text)
                print(str(year) + str(i) + str(j))
                year+=1
            else:              
                year = 2010
                break
                      
print(len(rating_pages))
# Out:
# 201010
# 201110
# 201210
# 201310
# 201410
# 201510
# 201610
# 201710
# 201810
# 201011
# 201111
# 201211
# 201311
# 201411
# 201511
# 201611
# 201711
# 201811
# 201012
# 201112
# 201212
# 201312
# 201412
# 201512
# 201612
# 201712
# 201812
# 201013
# 201113
# 201213
# 201313
# 201413
# 201513
# 201613
# 201713
# 201813
# 201020
# 201120
# 201220
# 201320
# 201420
# 201520
# 201620
# 201720
# 201820
# 201021
# 201121
# 201221
# 201321
# 201421
# 201521
# 201621
# 201721
# 201821
# 201022
# 201122
# 201222
# 201322
# 201422
# 201522
# 201622
# 201722
# 201822
# 201023
# 201123
# 201223
# 201323
# 201423
# 201523
# 201623
# 201723
# 201823
# 201030
# 201130
# 201230
# 201330
# 201430
# 201530
# 201630
# 201730
# 201830
# 201031
# 201131
# 201231
# 201331
# 201431
# 201531
# 201631
# 201731
# 201831
# 201032
# 201132
# 201232
# 201332
# 201432
# 201532
# ---------------------------------------------------------------------------
# ...

# %% [markdown]
# ### 정답 코드
#
# [티비랭킹닷컴 사이트](https://workey.codeit.kr/ratings/index)를 다시 크롤링해보려 합니다.
#
# 앞선 과제 TV 시청률 크롤링 pt. 2에서는 모든 달에 5주차가 있다고 가정하여 받아왔습니다.
#
# 이번에는 파싱을 활용해서 실제로 데이터가 있는 페이지만 받아오려고 하는데요.
#
# 2010년 1월부터 2018년 12월까지 모든 달에 대해, 데이터가 있는 모든 페이지의 HTML 코드(response의 text)를 rating_pages에 저장해 보세요.
#
# 주의: BeautifulSoup 타입으로 변환한 코드가 아닌, response의 text를 리스트에 저장하세요!

# %%
import requests
from bs4 import BeautifulSoup


rating_pages = []

for year in range(2010, 2019):
    for month in range(1, 13):
        while True:
            response = requests.get("https://workey.codeit.kr/ratings/index?year={0}&month={1}&weekIndex={2}".format(year, month, week))
            soup = BeautifulSoup(response.text, 'html.parser')
            if len(soup.select('.row td')) > 0 :
                rating_pages.append(response.text)
                week+=1
            else:
                week=0
                break
print(len(rating_pages))
print(rating_pages[0])
# Out:
# 468
# <!DOCTYPE html>
# <html lang="ko">
# <head>
#   <title>티비랭킹닷컴</title>
#   <meta charset="utf-8">
#   <link href="https://fonts.googleapis.com/css?family=Noto+Sans+KR" rel="stylesheet">
#   <style>
#     /* body start */
#     body {
#       font-family: 'Noto Sans KR', sans-serif;
#       margin: 0;
#     }
#
#     /* navigation bar start */
#     .nav-bar {
#       position: fixed;
#       width: 100%;
#       padding-top: 10px;
#       padding-bottom: 10px;
#       background-color: #ffffff;
#       box-shadow: 0 2px 4px 0 rgba(0, 0, 0, 0.14);
#       z-index: 1;
#     }
#
#     .nav-bar #tv-image {
#       margin-left: 78px;
#       margin-right: 15px;
#       height: 36px;
#       vertical-align: middle;
#     }
#
#     .nav-bar span {
#       font-weight: bold;
#       color: #4a4a4a;
#     }
#
#     /* date picker start */
#     .date-pick {
#       padding-top: 56px;
#       height: 200px;
#       background-color: #efefef;
#       margin-left: auto;
# ...

# %%
import requests
from bs4 import BeautifulSoup

# 기간 지정
years = list(range(2010, 2019))
months = list(range(1, 13))
weeks = list(range(0, 5))

# 빈 리스트 생성
rating_pages = []

for year in years:
    for month in months:
        for week in weeks:
            # HTML 코드 받아오기
            response = requests.get("https://workey.codeit.kr/ratings/index?year=" + str(year) + "&month=" + str(month) + "&weekIndex=" + str(week))

            # BeautifulSoup 타입으로 변환하기
            soup = BeautifulSoup(response.text, 'html.parser')

            # "row" 클래스가 1개를 넘는 경우만 페이지를 리스트에 추가
            if len(soup.select('.row')) > 1:
                rating_pages.append(response.text)

# 테스트 코드
print(len(rating_pages)) # 가져온 총 페이지 수 
print(rating_pages[0]) # 첫 번째 페이지의 HTML 코드

# %%
response = requests.get("https://workey.codeit.kr/ratings/index?year=2010&month=1&weekIndex=0")
soup = BeautifulSoup(response.text, 'html.parser')

print(soup.select('.row td'))
# Out:
# [<td class="rank">1</td>, <td class="channel">KBS2</td>, <td class="program">주말연속극(수상한삼형제)</td>, <td class="percent">33.4</td>, <td class="rank">2</td>, <td class="channel">KBS1</td>, <td class="program">일일연속극(다함께차차차)</td>, <td class="percent">33.1</td>, <td class="rank">3</td>, <td class="channel">KBS2</td>, <td class="program">해피선데이</td>, <td class="percent">27.1</td>, <td class="rank">4</td>, <td class="channel">MBC</td>, <td class="program">MBC연기대상2부</td>, <td class="percent">24.4</td>, <td class="rank">5</td>, <td class="channel">SBS</td>, <td class="program">주말극장(천만번사랑해)</td>, <td class="percent">24.2</td>, <td class="rank">6</td>, <td class="channel">MBC</td>, <td class="program">MBC방송연예대상2부</td>, <td class="percent">24.0</td>, <td class="rank">7</td>, <td class="channel">MBC</td>, <td class="program">MBC방송연예대상1부</td>, <td class="percent">22.4</td>, <td class="rank">8</td>, <td class="channel">SBS</td>, <td class="program">SBS연예대상2부</td>, <td class="percent">21.1</td>, <td cla
# ...

# %%
response = requests.get("https://workey.codeit.kr/ratings/index?year={0}&month={1}&weekIndex={2}".format(year, month, week))
response = requests.get("https://workey.codeit.kr/ratings/index?year=2010&month=2&weekIndex=0")
